# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (0.76.0)
# Requirement already satisfied: python-dotenv in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (1.2.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (from anthropic) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (from anthropic) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (from anthropic) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (from anthropic) (2.12.5)
# Requirement already satisfied: sniffio in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/hsztan/.local/share/mise/installs/python/3.14.2/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
def add_user_message(messages, text):
    user_message = { "role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = { "role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences
    }
    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# messages = []
# system="""
#     You are a patient math tutor.
#     Do not directly answer a student's questions.
#     Guide them to a solution step by step.
#     """

# add_user_message(messages, "Generate a one sentence movie idea")

# answer = chat(messages, temperature=1.0)
# answer

# %%
# messages = []

# while True:
#     user_input = input("> ")
#     print(">", user_input)
#     add_user_message(messages, user_input)

#     answer = chat(messages)

#     add_assistant_message(messages, answer)
#     print("---")
#     print(answer)
#     print("---")

# %%
# messages = []

# add_user_message(messages, "Write a 1 sentence description of a fake database")

# stream = client.messages.create(
#     model=model,
#     max_tokens=1000,
#     messages=messages,
#     stream=True
# )

# for event in stream:
#     print(event)

# %%
# messages = []

# add_user_message(messages, "Write a 1 sentence description of a fake database")

# %%
# messages = []

# add_user_message(messages, "Write a 1 sentence description of a fake database")

# with client.messages.stream(
#     model=model,
#     max_tokens=1000,
#     messages=messages,
# ) as stream:
#     for text in stream.text_stream:
#         print(text, end="")

# %%
# messages = []
# system="""
#     You are a patient math tutor.
#     Do not directly answer a student's questions.
#     Guide them to a solution step by step.
#     """

# add_user_message(messages, "Is tea or coffee better at breakfast?")

# add_assistant_message(messages, "Coffee is better because")

# answer = chat(messages, temperature=1.0)
# print(answer)

# %%
messages = []

add_user_message(messages, "Count from 1 to 10")

answer = chat(messages, stop_sequences=["5"])
answer
# Out:
# '1, 2, 3, 4, '

# %%
messages = []

add_user_message(messages, "Generate a very short event bridge rule as json")
add_assistant_message(messages, "```json")

text = chat(messages, stop_sequences=["```"])
text
# Out:
# '\n{\n  "Name": "OrderProcessingRule",\n  "EventPattern": {\n    "source": ["myapp.orders"],\n    "detail-type": ["Order Placed"]\n  },\n  "Targets": [\n    {\n      "Id": "1",\n      "Arn": "arn:aws:lambda:us-east-1:123456789012:function:ProcessOrder"\n    }\n  ],\n  "State": "ENABLED"\n}\n'

# %%
import json

json.loads(text)
# Out:
# {'Name': 'OrderProcessingRule',
#  'EventPattern': {'source': ['myapp.orders'], 'detail-type': ['Order Placed']},
#  'Targets': [{'Id': '1',
#    'Arn': 'arn:aws:lambda:us-east-1:123456789012:function:ProcessOrder'}],
#  'State': 'ENABLED'}
